# %%
#BOOTSTRAP_SERVERS='pkc-xrnwx.asia-south2.gcp.confluent.cloud:9092'
#API_KEY='EGAQNKIWYTRUP6SQ'
#API_SECRET='cfltaho2kx13KiqpQnkVwK2ZA4KM8L/KDdwhpSVc//2xRVvBbJ7v2OJM4bYX3MgQ'
#TOPIC_NAME='credit_card_transactions'

# %%
import json
kafka_connection_json=dbutils.secrets.get(scope="finguard-scope",key="kafka_connection_details")
kafka_config=json.loads(kafka_connection_json)
bootstrap_servers=kafka_config['bootstrap_servers']
api_key=kafka_config['api_key']
api_secret=kafka_config['api_secret']
topic=kafka_config['topic']

# %%
jaas_config=f'kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{'EGAQNKIWYTRUP6SQ'}" password="{'cfltaho2kx13KiqpQnkVwK2ZA4KM8L/KDdwhpSVc//2xRVvBbJ7v2OJM4bYX3MgQ'}";'

# %%
sample_batch=(spark.read.format("kafka")
              .option("kafka.bootstrap.servers",BOOTSTRAP_SERVERS)
              .option("subscribe",TOPIC_NAME)
            .option("kafka.security.protocol", "SASL_SSL")
        .option("kafka.sasl.mechanism", "PLAIN")
        .option("kafka.sasl.jaas.config", jaas_config)
        .option("startingOffsets","earliest")
        .load()
)

# %%
sample_batch.count()
# Out:
# 481

# %%
display(sample_batch)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th></tr></thead><tbody><tr><td>VFhONTIwMjUx</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>0</td><td>2026-09-05T06:20:43.690Z</td><td>0</td></tr><tr><td>VFhONDM2MzQ3</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>1</td><td>2026-09-05T06:20:44.092Z</td><td>0</td></tr><tr><td>VFhOMTU3NjQy</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>2</td><td>2026-09-05T06:20:46.326Z</td><td>0</td></tr><tr><td>VFhOMjYzMDUx</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>3</td><td>2026-09-05T06:20:46.528Z</td><td>0</td></tr><tr><td>VFhOMjA4NTUw</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>4</td><td>2026-09-05T06:20:48.550Z</td><td>0</td></tr><tr><td>VFhOMjcyODE1</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>5</td><td>2026-09-05T06:20:49.561Z</td><td>0</td></tr><tr><td>VFhOMjIyNjE3</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>6</td><td>2026-09-05T06:20:49.763Z</td><td>0</td></tr><tr><td>VFhONzk2NTYw</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>7</td><td>2026-09-05T06:20:51.978Z</td><td>0</td></tr><tr><td>VFhONTI0Njgz</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>8</td><td>2026-09-05T06:20:53.592Z</td><td>0</td></tr><tr><td>VFhOMTQzODI2</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>9</td><td>2026-09-05T06:20:56.621Z</td><td>0</td></tr><tr><td>VFhOMzcxMzA4</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>10</td><td>2026-09-05T06:21:01.068Z</td><td>0</td></tr><tr><td>VFhOMzA5NTA1</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>11</td><td>2026-09-05T06:21:01.270Z</td><td>0</td></tr><tr><td>VFhOMjgyNjk5</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>12</td><td>2026-09-05T06:21:03.895Z</td><td>0</td></tr><tr><td>VFhONDM2NDQy</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>13</td><td>2026-09-05T06:21:05.712Z</td><td>0</td></tr><tr><td>VFhOMjAwODQ0</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>14</td><td>2026-09-05T06:21:10.562Z</td><td>0</td></tr><tr><td>VFhOODg0NzQy</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>15</td><td>2026-09-05T06:21:10.765Z</td><td>0</td></tr><tr><td>VFhOMzA1NDc1</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>16</td><td>2026-09-05T06:21:12.786Z</td><td>0</td></tr><tr><td>VFhOMjYxOTg0</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>17</td><td>2026-09-05T06:21:13.191Z</td><td>0</td></tr><tr><td>VFhONDcxNjcz</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>18</td><td>2026-09-05T06:21:13.999Z</td><td>0</td></tr><tr><td>VFhONzA5MjQ4</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>19</td><td>2026-09-05T06:21:16.221Z</td><td>0</td></tr><tr><td>VFhONzczNzMw</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>20</td><td>2026-09-05T06:21:17.636Z</td><td>0</td></tr><tr><td>VFhONDI5NTQ2</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>21</td><td>2026-09-05T06:21:18.038Z</td><td>0</td></tr><tr><td>VFhONjYwMTYy</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>22</td><td>2026-09-05T06:21:18.442Z</td><td>0</td></tr><tr><td>VFhONjg5ODA5</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>23</td><td>2026-09-05T06:21:20.860Z</td><td>0</td></tr><tr><td>VFhOODY5NjMw</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>24</td><td>2026-09-05T06:21:22.676Z</td><td>0</td></tr><tr><td>VFhOOTkyMjM2</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>25</td><td>2026-09-05T06:21:22.878Z</td><td>0</td></tr><tr><td>VFhOMTQ0OTY2</td><td>...</td><td>credit_card_transactions</td><td>2</td><td>26</td><td>2026-09-05T06:21:25.563Z</td><td>0</td></tr><tr><td>V ...

# %%
from pyspark.sql.functions import col
parsed_batch=sample_batch.select(
col("key").cast("string"),
col("value").cast("string"),
col("topic"),
col("partition"),
col("offset"),
col("timestamp"),
col("timestampType")
)

# %%
display(parsed_batch)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th></tr></thead><tbody><tr><td>TXN520251</td><td>{"transaction_id": "TXN520251", "customer_id": "CUST000559", "card_number": "5461767929884254", "merchant_id": "MER0036", "merchant_name": "City Pantry 36", "merchant_category": "Grocery", "amount": 1909.77, "currency": "INR", "transaction_type": "ONLINE", "payment_channel": "POS", "device_id": "DEV4582", "city": "Jaipur", "country": "India", "transaction_timestamp": "2026-09-05T06:20:43Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>2</td><td>0</td><td>2026-09-05T06:20:43.690Z</td><td>0</td></tr><tr><td>TXN436347</td><td>{"transaction_id": "TXN436347", "customer_id": "CUST000666", "card_number": "4500507026086988", "merchant_id": "MER0158", "merchant_name": "Tasty Table 158", "merchant_category": "Restaurant", "amount": 41441.32, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "MOBILE_APP", "device_id": "DEV0666", "city": "Ahmedabad", "country": "India", "transaction_timestamp": "2026-09-05T06:20:44Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>2</td><td>1</td><td>2026-09-05T06:20:44.092Z</td><td>0</td></tr><tr><td>TXN157642</td><td>{"transaction_id": "TXN157642", "customer_id": "CUST000277", "card_number": "4827718129826656", "merchant_id": "MER0086", "merchant_name": "Spice Avenue 86", "merchant_category": "Restaurant", "amount": 78726.58, "currency": "INR", "transaction_type": "ONLINE", "payment_channel": "POS", "device_id": "DEV0277", "city": "Chennai", "country": "India", "transaction_timestamp": "2026-09-05T06:20:46Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>2</td><td>2</td><td>2026-09-05T06:20:46.326Z</td><td>0</td></tr><tr><td>TXN263051</td><td>{"transaction_id": "TXN263051", "customer_id": "CUST000033", "card_number": "5147379965075270", "merchant_id": "MER0122", "merchant_name": "Bistro Hub 122", "merchant_category": "Restaurant", "amount": 64834.44, "currency": "INR", "transaction_type": "ONLINE", "payment_channel": "MOBILE_APP", "device_id": "DEV6155", "city": "Chennai", "country": "India", "transaction_timestamp": "2026-09-05T06:20:46Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>2</td><td>3</td><td>2026-09-05T06:20:46.528Z</td><td>0</td></tr><tr><td>TXN208550</td><td>{"transaction_id": "TXN208550", "customer_id": "CUST000892", "card_number": "4733930493665386", "merchant_id": "MER0118", "merchant_name": "EventHub 118", "merchant_category": "Entertainment", "amount": 92697.48, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0892", "city": "Hyderabad", "country": "India", "transaction_timestamp": "2026-09-05T06:20:48Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>2</td><td>4</td><td>2026-09-05T06:20:48.550Z</td><td>0</td></tr><tr><td>TXN272815</td><td>{"transaction_id": "TXN272815", "customer_id": "CUST000563", "card_number": "4559821766191281", "merchant_id": "MER0067", "merchant_name": "HealthFirst 67", "merchant_category": "Pharmacy", "amount": 64084.46, "currency": "INR", "transaction_type": "ONLINE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0563", "city": "Jaipur", "country": "India", "transaction_timestamp": "2026-09-05T06:20:49Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>2</td><td>5</td><td>2026-09-05T06:20:49.561Z</td><td>0</td></tr><tr><td>TXN222617</td><td>{"transaction_id": "TXN222617", "customer_id": "CUST000434", "card_number": "5729949387430273", "merchant_id": "MER0081", "merchant_name": "Orbit Air 81", "merchant_category": "Airline", "amount": 35305.31, "c ...

# %%
streaming_df=(spark.readStream.format("kafka")
              .option("kafka.bootstrap.servers",BOOTSTRAP_SERVERS)
              .option("subscribe",TOPIC_NAME)
            .option("kafka.security.protocol", "SASL_SSL")
        .option("kafka.sasl.mechanism", "PLAIN")
        .option("kafka.sasl.jaas.config", jaas_config)
        .option("startingOffsets","earliest")
        .load()
)

# %%
from pyspark.sql.functions import col
parsed_streaming_df=streaming_df.select(
col("key").cast("string"),
col("value").cast("string"),
col("topic"),
col("partition"),
col("offset"),
col("timestamp"),
col("timestampType")
)

# %%
streaming_query=(parsed_streaming_df.writeStream.format("delta")
.outputMode("Append")
.option("checkpointLocation", "/Volumes/finguard/source/transactions/checkpoint/")
.trigger(availableNow=True)
.toTable("finguard.bronze.transactions_streaming_test")
)
print("Query Started with query id: ",streaming_query.id)
# Out:
# Query Started with query id:  7d763b05-abbd-4e0e-96ef-8646d40e8dad

# %%
# %sql
select * from finguard.bronze.transactions_streaming_test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th></tr></thead><tbody><tr><td>TXN823462</td><td>{"transaction_id": "TXN823462", "customer_id": "CUST000655", "card_number": "5156229493817359", "merchant_id": "MER0044", "merchant_name": "ShopSphere 44", "merchant_category": "Shopping", "amount": 34801.23, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0655", "city": "Lucknow", "country": "India", "transaction_timestamp": "2026-09-05T06:20:43Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>1</td><td>0</td><td>2026-09-05T06:20:43.286Z</td><td>0</td></tr><tr><td>TXN851197</td><td>{"transaction_id": "TXN851197", "customer_id": "CUST000239", "card_number": "5729293143866328", "merchant_id": "MER0194", "merchant_name": "Tasty Table 194", "merchant_category": "Restaurant", "amount": 48796.85, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0239", "city": "Mumbai", "country": "India", "transaction_timestamp": "2026-09-05T06:20:43Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>1</td><td>1</td><td>2026-09-05T06:20:43.891Z</td><td>0</td></tr><tr><td>TXN580430</td><td>{"transaction_id": "TXN580430", "customer_id": "CUST000345", "card_number": "4495528938911901", "merchant_id": "MER0043", "merchant_name": "HealthFirst 43", "merchant_category": "Pharmacy", "amount": 19053.0, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "MOBILE_APP", "device_id": "DEV6635", "city": "Jaipur", "country": "India", "transaction_timestamp": "2026-09-05T06:20:44Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>1</td><td>2</td><td>2026-09-05T06:20:44.697Z</td><td>0</td></tr><tr><td>TXN432585</td><td>{"transaction_id": "TXN432585", "customer_id": "CUST000128", "card_number": "4646471543799377", "merchant_id": "MER0146", "merchant_name": "Tasty Table 146", "merchant_category": "Restaurant", "amount": 49241.28, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0128", "city": "Bengaluru", "country": "India", "transaction_timestamp": "2026-09-05T06:20:45Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>1</td><td>3</td><td>2026-09-05T06:20:45.116Z</td><td>0</td></tr><tr><td>TXN891020</td><td>{"transaction_id": "TXN891020", "customer_id": "CUST000547", "card_number": "4614878245569640", "merchant_id": "MER0095", "merchant_name": "TripVista 95", "merchant_category": "Travel", "amount": 91168.61, "currency": "INR", "transaction_type": "PURCHASE", "payment_channel": "POS", "device_id": "DEV0547", "city": "Jaipur", "country": "India", "transaction_timestamp": "2026-09-05T06:20:46Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>1</td><td>4</td><td>2026-09-05T06:20:46.124Z</td><td>0</td></tr><tr><td>TXN437074</td><td>{"transaction_id": "TXN437074", "customer_id": "CUST000218", "card_number": "5110809969308484", "merchant_id": "MER0192", "merchant_name": "Grocer Go 192", "merchant_category": "Grocery", "amount": 63379.62, "currency": "INR", "transaction_type": "ONLINE", "payment_channel": "INTERNET_BANKING", "device_id": "DEV0218", "city": "Lucknow", "country": "India", "transaction_timestamp": "2026-09-05T06:20:46Z", "is_international": false, "status": "APPROVED"}</td><td>credit_card_transactions</td><td>1</td><td>5</td><td>2026-09-05T06:20:46.730Z</td><td>0</td></tr><tr><td>TXN606622</td><td>{"transaction_id": "TXN606622", "customer_id": "CUST000164", "card_number": "4304078593213346", "merchant_id": "MER0164", "merchant_name": "Retail City 164", "merchant_category": "Shopping", "amount ...
